# %%
import sys
import pandas as pd
import numpy as np

sys.path.insert(0, '../')

from automed import *
# Out:
# [16:21:03] cuDF not found: falling back to standalone pandas.

# %%
df = pd.read_csv('/Users/rudy/Documents/CHU/iias/baiddy_group/automl/src/perf_logger/tests_data/fetal_health.csv', sep=";")
y = df['label']
X = df.drop(columns=['label'])

# %%
automed = AutoMed()
automed.default_pipeline(fast=True)

# %%
automed.first_step.steps[0].steps[4].configuration
# Out:
# {'empty_threshold': {'description': 'Column with more or equal proportion of empty row                     will dropped. 1 will drop all columns',
#   'default': 0.5,
#   'value': 0.5}}

# %%
automed.first_step.steps[0].steps[4].configure('empty_threshold', 0.3)

# %%
automed.first_step.steps[0].steps[4].configuration
# Out:
# {'empty_threshold': {'description': 'Column with more or equal proportion of empty row                     will dropped. 1 will drop all columns',
#   'default': 0.5,
#   'value': 0.3}}

# %%
# automed.output[0].stacked_path[-3].step

# %%
# 0.9668874172185431 3 generation, 10 estimators

# %%
# 0.9629629629629629 5 generations, 20 estimators
